# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.2/78.2 GB disk)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 121MB/s]
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 101MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 92.8ms
# Speed: 15.6ms preprocess, 92.8ms inference, 829.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hx3HDHCfJimhOujYxOOC")
project = rf.workspace("trungduc-mmcnh").project("bienbao-7kgqo")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/coco128.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/content/runs/detect/train/weights/last.pt data=/content/coco128.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/traffic99.pt conf=0.25 source='/content/0014.jpg' save=True
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/0014.jpg: 448x640 3 stops, 2 forward_rights, 95.3ms
# Speed: 4.7ms preprocess, 95.3ms inference, 558.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=/content/runs/detect/train2/weights/last.pt data=/content/coco128.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/ĐỨC/runs/detect/train3/weights/best.pt conf=0.25 source='https://saigonatn.com/img_data/images/y-nghia-cua-bien-bao-giao-thong-duong-bo.jpg' save=True
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#
# ...
# 100% 171k/171k [00:00<00:00, 244kB/s]
# image 1/1 /content/y-nghia-cua-bien-bao-giao-thong-duong-bo.jpg: 416x640 3 stops, 3 forward_rights, 92.5ms
# Speed: 3.7ms preprocess, 92.5ms inference, 498.3ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt-get install unrar

# %%
# !unrar x /content/coco129.rar /content/
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/coco129.rar
#
# Creating    /content/coco129                                          OK
# Creating    /content/coco129/images                                   OK
# Creating    /content/coco129/images/train2017                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/coco129/labels                                   OK
# Creating    /content/coco129/labels/train2017                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...
